# %%
import pandas as pd
import sys 
import seaborn as sns
import matplotlib.pyplot as plt
sys.path.extend(['../'])

from tools import read_stat_history_date, read_stat_history_dates_combined, combine_result, create_pdf_filename

sns.set_theme(style="darkgrid")
sns.set(rc={'figure.figsize':(10,7)})
sns.set_context()
sns.set_palette("tab10")

# %%
test_setup = {"user": 20, "spawn_rate": 20, "runtime": "31s", "test_type": "visualization", "environment": "ec2-t2-m", "combine_method": "median"}

# %%
system_dfs_combined = read_stat_history_dates_combined(**test_setup)

# %%
rastless_df = system_dfs_combined["rastless"]
ax = sns.lineplot(data=rastless_df, x=rastless_df.index, y="User Count")
ax.set_title('Benchmark Setup')
filename = create_pdf_filename(f"./result_images/{test_setup['test_type']}", "user_count", test_setup)
plt.savefig(filename)

# %%
df_median_response = combine_result(system_dfs_combined, "Total Median Response Time")

# %%
ax = sns.lineplot(data=df_median_response)
ax.set(ylabel='Total Median Response Time [ms]')
ax.set_title('Visualization: Tile Requests')
filename = create_pdf_filename(f"./result_images/{test_setup['test_type']}", "total_median_response_time", test_setup)
plt.savefig(filename)

# %%
df_mean_response = combine_result(system_dfs_combined, "Total Average Response Time")

# %%
ax = sns.lineplot(data=df_mean_response)
ax.set(ylabel='Total Mean Response Time [ms]')
ax.set_title('Visualization: Tile Requests')
filename = create_pdf_filename(f"./result_images/{test_setup['test_type']}", "total_mean_response_time", test_setup)
plt.savefig(filename)

# %%
df_request_s = combine_result(system_dfs_combined, "Requests/s")

# %%
ax = sns.lineplot(data=df_request_s)
ax.set(ylabel='Requests/s')
ax.set_title('Visualization: Tile Requests')
filename = create_pdf_filename(f"./result_images/{test_setup['test_type']}", "requests_per_second", test_setup)
plt.savefig(filename)

# %%
df_request_total_count = combine_result(system_dfs_combined, "Total Request Count")

# %%
ax = sns.lineplot(data=df_request_total_count)
ax.set(ylabel="Total Request Count")
ax.set_title('Visualization: Tile Requests')
filename = create_pdf_filename(f"./result_images/{test_setup['test_type']}", "tile_requests_count", test_setup)
plt.savefig(filename)
